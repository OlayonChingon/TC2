# %%
# Teoría de los Circuitos 2        <img src="./logo_UTN.svg" align="right" width="150" />
# Curso: R4001    Año: 2024
## Tarea Semanal 1

#### Fabian Villada

# %%
![TS1enunciado](1.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Obtener la funcion de transferencia $\frac{V_2}{V_1}$ (Modulo, fase y diagramas de polos y ceros)
# </div>

# %%
$$ 1) V_3G_3 = (V_1-V_3) sC $$

$$ 2) (V_3-V_2) G_2 = (V_1-V_3) G_1 $$

##

$ De 2 : V_3G_2-V_2 = V_1G_1-V_3G_1 $

$ V_3(G_2+G_1) = V_1G_1 + V_2G_2 $

$$ 3) V_3=\frac{V_1G_1+V_2G_2}{G_2+G_1} $$

##
3 en 1: 

$\frac{V_1G_1+V_2G_2}{G_2+G_1} G_3 = V_1sC-(\frac{V_1G_1+V_2G_2}{G_2+G_1}) sC$

$V_1G_3G_1+V_2G_2G_3=V_1(G_2+G_1)=[V_1(G_2+G_1)-V_1G_1-V_2G_2] sC$

operando algebraicamente:

$\frac{V_2}{V_1} = -\frac{[G_3G_1-(G_2+G_1)sC+G_1sC]}{G_2G_3+G_2sC}$


$$\frac{V_2}{V_1} = \frac{s-\frac{G_3G_1}{G_2c}}{s+\frac{G_3}{C}}$$

$$\frac{V_2}{V_1} = \frac{s-\frac{R_2}{R_1}\frac{1}{R_3C}}{s+\frac{1}{R_3C}}$$


Considerando:

$R_1=R_2$

$𝜔_0=\frac{1}{R_3C}$

$$\frac{V_2}{V_1} = \frac{s-𝜔_0}{s+𝜔_0}$$

Falta analisis de modulo y fase

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> proponga una norma de impedancia y frecuencia de forma tal de llegar a una transferencia <b>normalizada</b>
# </div>

# %% [markdown]
# Suponiendo R1 = R2 = R3 propongo
#
# Norma de frecuencia : $𝜔_n = 𝜔_0$
#
# Norma de Impedancia : $Z_n = R $  con $R=R_1=R_2=R_3$
#
# Por lo tanto la transferencia normalizada seria:
#
# $$\frac{V_2}{V_1} = \frac{s_n-1}{s_n+1}$$
#
# $R_xn = \frac{R_xn}{R}$

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Simulacion <b>funcion de transferencia normalizada</b> en python
# </div>

# %%
#Created on Mon Apr 10 07:01:43 2024

#Tarea Semanal 1 R4001 2024

#@author: Fabian Villada


from scipy.signal import TransferFunction
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot
import matplotlib.pyplot as plt



my_tf = TransferFunction([1,-1],[1,1])


bodePlot(my_tf, fig_id=1)
pzmap(my_tf, fig_id=2)
GroupDelay(my_tf, fig_id=3)
plt.ylim([-1,1])
# Out:
# /home/fabian/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# (-1.0, 1.0)

# %%
#Created on Mon Apr 10 07:01:43 2024

#Tarea Semanal 1 R4001 2024

#@author: Fabian Villada




from scipy.signal import TransferFunction
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot
import matplotlib.pyplot as plt

my_tf = TransferFunction([1, -1], [1, 1])

fig1, axs = bodePlot(my_tf, fig_id=1)  # Obtener la figura y las subtramas

axs[0].set_ylim(-1, 1)  # Establecer límites del eje y en la subtrama 0

pzmap(my_tf, fig_id=2)
GroupDelay(my_tf, fig_id=3)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> Simulacion <b>Red normalizada</b> en LTspice
# </div>

# %% [markdown]
# Considerando R1=R2=R3 y c = 10uF
#
# ![TS1_SimulacionLTspice](2.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> ¿Que tipo de filtro es?¡Que utilidad podria tener este tipo de circuitos?
# </div>

# %% [markdown]
# En el analisis de modulo de la transferencia $\frac{V_2}{V_1} = \frac{s-𝜔_0}{s+𝜔_0}$ para jw=0 pasan los bajos y para jw tendiendo a alta frecuencia tendriamos una indeterminacion resoluble que indica que pasan los altos.
#
# Segun las simulaciones el circuito <b>Produce una ROTACION DE FASE</b>.
#
# Por lo tanto podriamos utilizar esta etapa para invertir la señal en fase para exitar etapas posteriores.
